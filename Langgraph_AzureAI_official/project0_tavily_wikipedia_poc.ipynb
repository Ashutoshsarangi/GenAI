# %% [markdown]
# ## Integration of Tavily Search

# %%
from langchain_tavily import TavilySearch

tool = TavilySearch(max_results=2)

# %%
tool.invoke({"query": "What happened at the last wimbledon"})
# Out:
# {'query': 'What happened at the last wimbledon',
#  'follow_up_questions': None,
#  'answer': None,
#  'images': [],
#  'results': [{'url': 'https://www.youtube.com/watch?v=DinvOiDhEyc',
#    'title': 'What went wrong | Carlos Alcaraz | Post-match Press ...',
#    'content': '"A tournament I always dreamed of" | Jannik Sinner | Post-match Press Conference | Wimbledon 2025 · DRAMATIC ending to the final | The last 26',
#    'score': 0.24058765,
#    'raw_content': None},
#   {'url': 'https://www.cbc.ca/sports/tennis/2025-wimbledon-men-final-recap-1.7584001',
#    'title': 'Sinner beats 2-time defending champion Alcaraz to win 1st ...',
#    'content': 'Jannik Sinner defeated two-time defending champion Carlos Alcaraz 4-6, 6-4, 6-4, 6-4 on Sunday to win his first Wimbledon championship and',
#    'score': 0.22674122,
#    'raw_content': None}],
#  'response_time': 1.15}

# %% [markdown]
# ## Wikipedia Integration

# %%
from langchain_community.tools import WikipediaQueryRun
from langchain_community.utilities import WikipediaAPIWrapper

wikipedia = WikipediaQueryRun(api_wrapper=WikipediaAPIWrapper())

wikipedia.invoke("HUNTER X HUNTER")
# Out:
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# File ~/Desktop/Master/Learning/Gen AI/.venv/lib/python3.11/site-packages/urllib3/connection.py:174, in HTTPConnection._new_conn(self)
#     173 try:
# --> 174     conn = connection.create_connection(
#     175         (self._dns_host, self.port), self.timeout, **extra_kw
#     176     )
#     178 except SocketTimeout:
#
# File ~/Desktop/Master/Learning/Gen AI/.venv/lib/python3.11/site-packages/urllib3/util/connection.py:72, in create_connection(address, timeout, source_address, socket_options)
#      68     return six.raise_from(
#      69         LocationParseError(u"'%s', label empty or too long" % host), None
#      70     )
# ---> 72 for res in socket.getaddrinfo(host, port, family, socket.SOCK_STREAM):
#      73     af, socktype, proto, canonname, sa = res
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/socket.py:962, in getaddrinfo(host, port, family, type, proto, flags)
#     961 addrlist = []
# --> 962 for res in _socket.getaddrinfo(host, port, family, type, proto, flags):
#     963     af, socktype, proto, canonname, sa = res
#
# gaierror: [Errno 8] nodename nor servname provided, or not known
#
# During handling of the above exception, another exception occurred:
#
# NewConnectionError                        Traceback (most recent call last)
# File ~/Desktop/Master/Learning/Gen AI/.venv/lib/python3.11/site-packages/urllib3/connectionpool.py:713, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     712 if is_new_proxy_conn and http_tunnel_required:
# --> 713     self._prepare_proxy(conn)
#     715 # Make the request on the httplib connection object.
#
# File ~/Desktop/Master/Learning/Gen AI/.venv/lib/python3.11/site-packages/urllib3/connectionpool.py:1015, in HTTPSConnectionPool._prepare_proxy(self, conn)
#    1013     conn.tls_in_tls_required = True
# -> 1015 conn.connect()
#
# File ~/Desktop/Master/Learning/Gen AI/.venv/lib/python3.11/site-packages/urllib3/connection.py:363, in HTTPSConnection.connect(self)
#     361 def connect(self):
#     362     # Add certificate verification
# --> 363     self.sock = conn = self._new_conn()
#     364     hostname = self.host
#
# File ~/Desktop/Master/Learning/Gen AI/.venv/lib/python3.11/site-packages/urllib3/connection.py:186, in HTTPConnection._new_conn(self)
#     185 except SocketError as e:
# --> 186     raise NewConnectionError(
#     187         self, "Failed to establish a new connection: %s" % e
#     188     )
#     190 return conn
#
# NewConnectionError: <urllib3.connection.HTTPSConnection object at 0x10c021710>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known
#
# During handling of the above exception, another exception occurred:
#
# MaxRetryError                             Traceback (most recent call last)
# File ~/Desktop/Master/Learning/Gen AI/.venv/lib/python3.11/site-packages/requests/adapters.py:667, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     666 try:
# --> 667     resp = conn.urlopen(
#     668         method=request.method,
#     669         url=url,
#     670         body=request.body,
#     671         headers=request.headers,
#     672         redirect=False,
#     673         assert_same_host=False,
#     674         preload_content=False,
#     675         decode_content=False,
#     676         retries=self.max_retries,
#     677         timeout=timeout,
#     678         chunked=chunked,
#     679     )
#     681 except (ProtocolError, OSError) as err:
#
# File ~/Desktop/Master/Learning/Gen AI/.venv/lib/python3.11/site-packages/urllib3/connectionpool.py:802, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     800     e = ProtocolError("Connection aborted.", e)
# --> 802 retries = retries.increment(
#     803     method, url, error=e, _pool=self, _stacktrace=sys.exc_info()[2]
#     804 )
#     805 retries.sleep()
#
# File ~/Desktop/Master/Learning/Gen AI/.venv/lib/python3.11/site-packages/urllib3/util/retry.py:594, in Retry.increment(self, method, url, response, error, _pool, _stacktrace)
#     593 if new_retry.is_exhausted():
# --> 594     raise MaxRetryError(_pool, url, error or ResponseError(cause))
#     596 log.debug("Incremented Retry for (url='%s'): %r", url, new_retry)
#
# MaxRetryError: HTTPSConnectionPool(host='en.wikipedia.org', port=443): Max retries exceeded with url: /w/api.php?list=search&srprop=&srlimit=3&limit=3&srsearch=HUNTER+X+HUNTER&format=json&action=query (Caused by ProxyError('Cannot connect to proxy.', NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x10c021710>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known')))
#
# During handling of the above exception, another exception occurred:
#
# ProxyError                                Traceback (most recent call last)
# Cell In[6], line 6
#       2 from langchain_community.utilities import WikipediaAPIWrapper
#       4 wikipedia = WikipediaQueryRun(api_wrapper=WikipediaAPIWrapper())
# ----> 6 wikipedia.invoke("HUNTER X HUNTER")
#
# File ~/Desktop/Master/Learning/Gen AI/.venv/lib/python3.11/site-packages/langchain_core/tools/base.py:599, in BaseTool.invoke(self, input, config, **kwargs)
#     591 @override
#     592 def invoke(
#     593     self,
#    (...)    596     **kwargs: Any,
#     597 ) -> Any:
#     598     tool_input, kwargs = _prep_run_args(input, config, **kwargs)
# --> 599     return self.run(tool_input, **kwargs)
#
# File ~/Desktop/Master/Learning/Gen AI/.venv/lib/python3.11/site-packages/langchain_core/tools/base.py:883, in BaseTool.run(self, tool_input, verbose, start_color, color, callbacks, tags, metadata, run_name, run_id, config, tool_call_id, **kwargs)
#     881 if error_to_raise:
#     882     run_manager.on_tool_error(error_to_raise)
# --> 883     raise error_to_raise
#     884 output = _format_output(content, artifact, tool_call_id, self.name, status)
#     885 run_manager.on_tool_end(output, color=color, name=self.name, **kwargs)
#
# File ~/Desktop/Master/Learning/Gen AI/.venv/lib/python3.11/site-packages/langchain_core/tools/base.py:852, in BaseTool.run(self, tool_input, verbose, start_color, color, callbacks, tags, metadata, run_name, run_id, config, tool_call_id, **kwargs)
#     850     if config_param := _get_runnable_config_param(self._run):
#     851         tool_kwargs = tool_kwargs | {config_param: config}
# --> 852     response = context.run(self._run, *tool_args, **tool_kwargs)
#     853 if self.response_format == "content_and_artifact":
#     854     if not isinstance(response, tuple) or len(response) != 2:
#
# File ~/Desktop/Master/Learning/Gen AI/.venv/lib/python3.11/site-packages/langchain_community/tools/wikipedia/tool.py:38, in WikipediaQueryRun._run(self, query, run_manager)
#      32 def _run(
#      33     self,
#      34     query: str,
#      35     run_manager: Optional[CallbackManagerForToolRun] = None,
#      36 ) -> str:
#      37     """Use the Wikipedia tool."""
# ---> 38     return self.api_wrapper.run(query)
#
# File ~/Desktop/Master/Learning/Gen AI/.venv/lib/python3.11/site-packages/langchain_community/utilities/wikipedia.py:49, in WikipediaAPIWrapper.run(self, query)
#      47 def run(self, query: str) -> str:
#      48     """Run Wikipedia search and get page summaries."""
# ---> 49     page_titles = self.wiki_client.search(
#      50         query[:WIKIPEDIA_MAX_QUERY_LENGTH], results=self.top_k_results
#      51     )
#      52     summaries = []
#      53     for page_title in page_titles[: self.top_k_results]:
#
# File ~/Desktop/Master/Learning/Gen AI/.venv/lib/python3.11/site-packages/wikipedia/util.py:28, in cache.__call__(self, *args, **kwargs)
#      26   ret = self._cache[key]
#      27 else:
# ---> 28   ret = self._cache[key] = self.fn(*args, **kwargs)
#      30 return ret
#
# File ~/Desktop/Master/Learning/Gen AI/.venv/lib/python3.11/site-packages/wikipedia/wikipedia.py:103, in search(query, results, suggestion)
#     100 if suggestion:
#     101   search_params['srinfo'] = 'suggestion'
# --> 103 raw_results = _wiki_request(search_params)
#     105 if 'error' in raw_results:
#     106   if raw_results['error']['info'] in ('HTTP request timed out.', 'Pool queue is full'):
#
# File ~/Desktop/Master/Learning/Gen AI/.venv/lib/python3.11/site-packages/wikipedia/wikipedia.py:737, in _wiki_request(params)
#     734   wait_time = (RATE_LIMIT_LAST_CALL + RATE_LIMIT_MIN_WAIT) - datetime.now()
#     735   time.sleep(int(wait_time.total_seconds()))
# --> 737 r = requests.get(API_URL, params=params, headers=headers)
#     739 if RATE_LIMIT:
#     740   RATE_LIMIT_LAST_CALL = datetime.now()
#
# File ~/Desktop/Master/Learning/Gen AI/.venv/lib/python3.11/site-packages/requests/api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)     70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File ~/Desktop/Master/Learning/Gen AI/.venv/lib/python3.11/site-packages/requests/api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File ~/Desktop/Master/Learning/Gen AI/.venv/lib/python3.11/site-packages/requests/sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File ~/Desktop/Master/Learning/Gen AI/.venv/lib/python3.11/site-packages/requests/sessions.py:724, in Session.send(self, request, **kwargs)
#     721 if allow_redirects:
#     722     # Redirect resolving generator.
#     723     gen = self.resolve_redirects(r, request, **kwargs)
# --> 724     history = [resp for resp in gen]
#     725 else:
#     726     history = []
#
# File ~/Desktop/Master/Learning/Gen AI/.venv/lib/python3.11/site-packages/requests/sessions.py:724, in <listcomp>(.0)
#     721 if allow_redirects:
#     722     # Redirect resolving generator.
#     723     gen = self.resolve_redirects(r, request, **kwargs)
# --> 724     history = [resp for resp in gen]
#     725 else:
#     726     history = []
#
# File ~/Desktop/Master/Learning/Gen AI/.venv/lib/python3.11/site-packages/requests/sessions.py:265, in SessionRedirectMixin.resolve_redirects(self, resp, req, stream, timeout, verify, cert, proxies, yield_requests, **adapter_kwargs)
#     263     yield req
#     264 else:
# --> 265     resp = self.send(
#     266         req,
#     267         stream=stream,
#     268         timeout=timeout,
#     269         verify=verify,
#     270         cert=cert,
#     271         proxies=proxies,
#     272         allow_redirects=False,
#     273         **adapter_kwargs,
#     274     )
#     276     extract_cookies_to_jar(self.cookies, prepared_request, resp.raw)
#     278     # extract redirect url, if any, for the next loop
#
# File ~/Desktop/Master/Learning/Gen AI/.venv/lib/python3.11/site-packages/requests/sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File ~/Desktop/Master/Learning/Gen AI/.venv/lib/python3.11/site-packages/requests/adapters.py:694, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     691     raise RetryError(e, request=request)
#     693 if isinstance(e.reason, _ProxyError):
# --> 694     raise ProxyError(e, request=request)
#     696 if isinstance(e.reason, _SSLError):
#     697     # This branch is for urllib3 v1.22 and later.
#     698     raise SSLError(e, request=request)
#
# ProxyError: HTTPSConnectionPool(host='en.wikipedia.org', port=443): Max retries exceeded with url: /w/api.php?list=search&srprop=&srlimit=3&limit=3&srsearch=HUNTER+X+HUNTER&format=json&action=query (Caused by ProxyError('Cannot connect to proxy.', NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x10c021710>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known')))
